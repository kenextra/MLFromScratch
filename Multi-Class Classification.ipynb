# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from utils import display_data, one_vs_all, predict_ova

# %% [markdown]
# # Load data

# %%
data = loadmat("data/ex3data1.mat")

# %%
print(data.keys())

X = data['X']
print(X.shape)

y = data['y']
print(y.shape)

# %% [markdown]
# # Visualize data

# %%
# Randomly select data points to display
m, n = X.shape
indices = np.random.permutation(m)
# indices[0:100]

# %%
data_points = X[indices[0:100], :]
nrows = data_points.shape[0]

# %%
for i, da in enumerate(data_points):
    sp = plt.subplot(10, 10, i+1, facecolor='red')
    sp.axis('Off')
    # max_val = np.max(np.abs(da))
    data_points_ = np.reshape(da, (20,20), order='F')# da.reshape(400, 1)
    data_points_1 = data_points_.reshape(20,20)
    # data_points_1 = ndimage.rotate(data_points_1, 45, reshape=False)
    plt.imshow(data_points_1, cmap='gray', interpolation = 'bicubic') # / max_val

# %%
display_data(data_points)

# %% [markdown]
# # Train the model

# %%
num_labels = 10
lambd = 0.1

# %%
all_theta = one_vs_all(X, y, num_labels, lambd)

# %% [markdown]
# # Evaluate model accuracy

# %%
pred = predict_ova(all_theta, X)

print(f'Train Accuracy: {np.mean(pred == y) * 100:.1f}%')
# Out:
# Train Accuracy: 96.4%
